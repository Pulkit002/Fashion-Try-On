# %%
# !git clone https://github.com/facebookresearch/detectron2

# %%
# !unzip '/content/detectron2.zip'

# %%
# !python -m pip install -e detectron2

# %%
# %cd detectron2/projects/DensePose
# !pip install av>=8.0.3 opencv-python-headless>=4.5.3.56 scipy>=1.5.4
# Out:
# /content/detectron2/projects/DensePose

# %%
# !mkdir ./image_path

# %%
# !cp /content/test/image/0000* ./image_path/

# %%
# !python apply_net.py show configs/densepose_rcnn_R_50_FPN_s1x.yaml \
https://dl.fbaipublicfiles.com/densepose/densepose_rcnn_R_50_FPN_s1x/165712039/model_final_162be9.pkl \
image_path dp_segm -v
# Out:
# [03/18 20:08:40 apply_net]: Loading config from configs/densepose_rcnn_R_50_FPN_s1x.yaml
# [03/18 20:08:40 apply_net]: Loading model from https://dl.fbaipublicfiles.com/densepose/densepose_rcnn_R_50_FPN_s1x/165712039/model_final_162be9.pkl
# model_final_162be9.pkl: 256MB [00:01, 255MB/s]
# [03/18 20:08:43 apply_net]: Loading data from image_path
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [03/18 20:08:45 apply_net]: Processing image_path/densepose.jpg
# [03/18 20:08:45 apply_net]: Output saved to ./image-densepose/densepose.jpg

# %%
import matplotlib.pyplot as plt
from PIL import Image

image1 = Image.open('/content/detectron2/projects/DensePose/image_path/densepose.jpg')
image2 = Image.open('/content/detectron2/projects/DensePose/image-densepose/densepose.jpg')

fig, axes = plt.subplots(1, 2)

axes[0].imshow(image1)
axes[0].set_title('Input')

axes[1].imshow(image2)
axes[1].set_title('Dense Pose')

plt.show()
